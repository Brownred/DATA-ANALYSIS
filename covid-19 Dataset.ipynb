# %%
import pandas as pd
import numpy as np
import random

# %%
# Read The data
Covid = pd.read_excel("covid-19 data.xlsx")

# %% [markdown]
# ### View the data

# %%
# data shape
Covid.shape
# Out:
# (211595, 67)

# %%
Covid.tail(8)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 211587      ZWE    Africa  Zimbabwe  2022-08-19     256596.0       17.0
# 211588      ZWE    Africa  Zimbabwe  2022-08-20     256616.0       20.0
# 211589      ZWE    Africa  Zimbabwe  2022-08-21     256624.0        8.0
# 211590      ZWE    Africa  Zimbabwe  2022-08-22     256628.0        4.0
# 211591      ZWE    Africa  Zimbabwe  2022-08-23     256628.0        0.0
# 211592      ZWE    Africa  Zimbabwe  2022-08-24     256628.0        0.0
# 211593      ZWE    Africa  Zimbabwe  2022-08-25     256675.0       47.0
# 211594      ZWE    Africa  Zimbabwe  2022-08-26     256682.0        7.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 211587              10.571        5589.0         0.0                0.286
# 211588              13.429        5592.0         3.0                0.714
# 211589              12.143        5592.0         0.0                0.571
# ...

# %% [markdown]
# To view a summury of the Covid dataset, I used The _*describe()*_ Function

# %%
Covid.describe(include="all")
# Use "Covid.info()" To get the technical summary of the dataset eg.
# the amount of memory/RAM used to hold the DataFrame
# Out:
#        iso_code continent   location        date   total_cases     new_cases  \
# count    211595    199377     211595      211595  2.030510e+05  2.028080e+05
# unique      244         6        244         969           NaN           NaN
# top         ARG    Africa  Argentina  2021-08-25           NaN           NaN
# freq        969     48988        969         243           NaN           NaN
# mean        NaN       NaN        NaN         NaN  3.981466e+06  1.262202e+04
# std         NaN       NaN        NaN         NaN  2.497046e+07  8.710392e+04
# min         NaN       NaN        NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN        NaN         NaN  3.674500e+03  0.000000e+00
# 50%         NaN       NaN        NaN         NaN  4.366200e+04  6.300000e+01
# 75%         NaN       NaN        NaN         NaN  4.684245e+05  1.007000e+03
# max         NaN       NaN        NaN         NaN  6.000144e+08  4.081689e+06
#
# ...

# %% [markdown]
# ##### Check for missing values:

# %%
Covid.isna().sum()
Covid.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   12218
# location                                        0
# date                                            0
# total_cases                                  8544
#                                             ...
# human_development_index                     42116
# excess_mortality_cumulative_absolute       204462
# excess_mortality_cumulative                204462
# excess_mortality                           204442
# excess_mortality_cumulative_per_million    204462
# Length: 67, dtype: int64

# %% [markdown]
# Check How pandas Interpreted each of the columns data types by using the _*dtypes*_ attribute

# %%
Covid.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# ### Get the total cases, total deaths per continent

# %% [markdown]
# ### Break the dataset into smaller subsets
# ##### Filter specific rows from a DataFrame
# iminterested in the data with total cases greater than 500,000

# %%
High_total_cases = Covid[Covid["total_cases"] >500000]
High_total_cases.shape
# High_total_cases.describe(include="all")
# Out:
# (49493, 67)

# %%
High_total_cases.head(5)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 1060  OWID_AFR       NaN   Africa  2020-07-07     507792.0    17466.0
# 1061  OWID_AFR       NaN   Africa  2020-07-08     522535.0    14743.0
# 1062  OWID_AFR       NaN   Africa  2020-07-09     541725.0    19190.0
# 1063  OWID_AFR       NaN   Africa  2020-07-10     559430.0    17705.0
# 1064  OWID_AFR       NaN   Africa  2020-07-11     578216.0    18786.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1060           14700.143       11975.0       365.0              261.286  ...
# 1061           14918.714       12232.0       257.0              261.143  ...
# 1062           15631.286       12457.0       225.0              259.143  ...
# 1063           15994.857       12763.0       306.0              268.714  ...
# 1064           16466.429       12988.0       225.0              272.143  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# I want to work with the data for which the continent is known. Do away with the data in continent column that is not known(NaN)

# %%
# to check the total number af null values in continent colum
High_total_cases["continent"].isna().sum()


#Case_per_continent = High_total_cases[High_total_cases["continent"].notna()]


# alternative is using the drop method
Case_per_continent = High_total_cases.dropna(subset=["continent"])

# %%
# List The continent name
Continents_unique = Case_per_continent.continent.unique()
list(Continents_unique)
# Out:
# ['South America', 'Oceania', 'Europe', 'Asia', 'North America', 'Africa']

# %%
# Grouping the data by continents and summing them
Case_per_continent = Case_per_continent.groupby(['continent'])[["total_cases","total_deaths","total_vaccinations"]].sum()
Case_per_continent
# Out:
#                 total_cases  total_deaths  total_vaccinations
# continent
# Africa         2.814013e+09    73571632.0        1.869015e+10
# Asia           5.173083e+10   612184121.0        1.562445e+12
# Europe         6.022377e+10   824300395.0        3.704422e+11
# North America  3.956976e+10   709807448.0        3.244158e+11
# Oceania        1.569406e+09     1943734.0        1.405431e+10
# South America  2.484151e+10   666498491.0        2.327302e+11

# %%
# Continent shouldnt be an index
Case_per_continent.reset_index(level=0,inplace=True)
Case_per_continent
# Out:
#        continent   total_cases  total_deaths  total_vaccinations
# 0         Africa  2.814013e+09    73571632.0        1.869015e+10
# 1           Asia  5.173083e+10   612184121.0        1.562445e+12
# 2         Europe  6.022377e+10   824300395.0        3.704422e+11
# 3  North America  3.956976e+10   709807448.0        3.244158e+11
# 4        Oceania  1.569406e+09     1943734.0        1.405431e+10
# 5  South America  2.484151e+10   666498491.0        2.327302e+11
